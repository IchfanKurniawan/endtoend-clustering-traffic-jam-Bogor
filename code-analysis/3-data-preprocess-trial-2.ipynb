# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Setting
sns.despine(left=True, bottom=True)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format','{:.4f}'.format)
sns.set()

# %matplotlib inline

# %%
jams = pd.read_parquet('..\\dataset\\aggregate_median_jams_bogor_eda.parquet')

# %%
jams.sample(3)
# Out:
#                               street  median_length  median_delay  \
# 18951                       pahlawan      1143.0000       61.0000
# 7260   brigjen saptadji hadi prawira      1631.0000      113.0000
# 5881                         unknown       182.0000      141.0000
#
#        median_speed_kmh  total_records        id       date  median_level  \
# 18951           22.4600              7  34197103 2022-07-17        1.0000
# 7260            22.2800              5  33722176 2022-07-10        2.0000
# 5881             3.8100              8  33669403 2022-07-09        3.0000
#
#                                                 geometry           date_time  \
# 18951  MULTILINESTRING ((106.794985 -6.607735, 106.79... 2022-07-17 17:00:00
# 7260   MULTILINESTRING ((106.771742 -6.576096, 106.77... 2022-07-10 21:00:00
# 5881   MULTILINESTRING ((106.847722 -6.654044, 106.84... 2022-07-09 17:00:00
#
#        weekday  month  day  is_weekday  hour  is_working_hour  is_morning  \
# 18951        6      7   17           0    17                0           0
# 7260         6      7   10           0    21                0           0
# 5881         5      7    9           0    17                0           0
#
#        is_lunch  is_late_afternoon  is_late_night
# 18951         0                  1              0
# 7260          0                  0              0
# 5881          0                  1              0

# %% [markdown]
# ## Preprocess

# %%
jams_preprocess = jams.copy()
jams_preprocess = jams_preprocess.drop(['id', 'date', 'geometry', 'date_time'], axis=1)

# %%
jams_preprocess['time_span'] = np.where((jams.hour >= 3) & (jams.hour < 6), 1, 
                                        np.where((jams.hour >= 6) & (jams.hour < 10), 2,
                                        np.where((jams.hour >= 10) & (jams.hour < 15), 3,
                                        np.where((jams.hour >= 15) & (jams.hour < 18), 4,
                                        np.where((jams.hour >= 18) & (jams.hour < 22), 5, 6)))))

# %%
jams_preprocess.sample(3)
# Out:
#                    street  median_length  median_delay  median_speed_kmh  \
# 96443  n6 jalan raya baru      1980.0000       72.0000           33.3400
# 66310   jenderal sudirman      1263.0000      167.5000           16.3900
# 33903             merdeka       713.0000      134.0000           11.8000
#
#        total_records  median_level  weekday  month  day  is_weekday  hour  \
# 96443              3        1.0000        4      9    2           1     7
# 66310              6        3.0000        6      8   14           0    13
# 33903              9        2.0000        1      7   26           1    19
#
#        is_working_hour  is_morning  is_lunch  is_late_afternoon  \
# 96443                0           1         0                  0
# 66310                0           0         1                  0
# 33903                0           0         0                  0
#
#        is_late_night  time_span
# 96443              0          2
# 66310              0          3
# 33903              0          5

# %%
jams_preprocess.isna().sum().max()
# Out:
# 0

# %%
jams_preprocess = jams_preprocess.drop_duplicates()

# %%
jams_preprocess.sample(3)
# Out:
#                    street  median_length  median_delay  median_speed_kmh  \
# 16049  exit baranangsiang       585.0000      434.0000            4.5000
# 51514        tol jagorawi      3237.0000       62.0000           59.3800
# 54745              pemuda       622.0000       95.0000           14.6400
#
#        total_records  median_level  weekday  month  day  is_weekday  hour  \
# 16049             58        4.0000        5      7   16           0    14
# 51514              1        1.0000        5      8    6           0     4
# 54745              1        3.0000        6      8    7           0    14
#
#        is_working_hour  is_morning  is_lunch  is_late_afternoon  \
# 16049                0           0         0                  0
# 51514                0           0         0                  0
# 54745                0           0         0                  0
#
#        is_late_night  time_span
# 16049              0          3
# 51514              0          1
# 54745              0          3

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Feature Engineer: Selected Numerical

# %%
temp_df = (
    jams_preprocess
    .loc[:, ['median_length', 'median_delay', 'median_speed_kmh', 'total_records', 'median_level', 'street']]
    .groupby('street')
    .agg(['mean', 'median', 'std'])
)

temp_df = temp_df.fillna(0)
temp_df.columns = [f'{col[0]}__{col[1]}' for col in temp_df.columns]

# %%
temp_df.head()
# Out:
#                    median_length__mean  median_length__median  \
# street
# achmad adnawijaya             705.8876               795.0000
# ah nasution                   294.0000               294.0000
# airlangga                     175.0000               175.0000
# akses tol tajur               178.9839               182.0000
# al hasanah                    205.0000               205.0000
#
#                    median_length__std  median_delay__mean  \
# street
# achmad adnawijaya            274.5424            115.1278
# ah nasution                    0.0000            251.1562
# airlangga                      0.0000            136.0000
# akses tol tajur                4.8862            178.3226
# al hasanah                     0.0000            119.0000
#
#                    median_delay__median  median_delay__std  \
# street
# achmad adnawijaya               93.0000            81.8696
# ah nasution                    145.2500           299.1715
# airlangga                      136.0000             2.8284
# akses tol tajur                159.0000            65.7680
# al hasanah                     119.0000             0.0000
#
#                    median_speed_kmh__mean  median_speed_kmh__median  \
# street
# achmad adnawijaya                 13.1786                   13.9800
# ah nasution                        4.1166                    3.8050
# airlangga                          3.7000                    3.7000
# akses tol tajur                    3.4908                    3.4950
# al hasanah                         4.5200                    4.5200
#
#                    median_speed_kmh__std  total_records__mean  \
# street
# achmad adnawijaya                 4.5660              11.8303
# ah nasution                       1.8658               2.8125
# airlangga                         0.0566               4.0000
# akses tol tajur                   0.9548              13.6452
# al hasanah                        0.0000               9.0000
#
#                    total_records__median  total_records__std  \
# street
# achmad adnawijaya                 8.0000             11.7387
# ah nasution                       2.0000              2.2352
# airlangga                         4.0000              1.4142
# akses tol tajur                  12.0000             11.8983
# al hasanah                        9.0000              0.0000
#
#                    median_level__mean  median_level__median  median_level__std
# street
# achmad adnawijaya              2.3871                2.0000             0.8124
# ah nasution                    2.2500                2.0000             0.9504
# airlangga                      3.5000                3.5000             0.7071
# akses tol tajur                4.0000                4.0000             0.0000
# al hasanah                     4.0000                4.0000             0.0000

# %% [markdown]
# ### Occurance

# %%
# overall occurance
temp_df = (
    jams_preprocess
    .loc[:, ['street', 'median_level']]
    .groupby('street', as_index=False)
    .count()
)

temp_df = temp_df.rename(columns={'median_level': 'overall_occurance'})

# %%
# occurance per time span
time_span = 1
temp_df = (
    jams_preprocess
    .query('time_span == @time_span')
    .loc[:, ['street', 'median_level']]
    .groupby('street')
    .count()
)

temp_df = temp_df.rename(columns={'median_level': f'occurance_time_span_{time_span}'})

# %%
# occurance per weekday
weekday = 1
temp_df = (
    jams_preprocess
    .query('weekday == @weekday')
    .loc[:, ['street', 'median_level']]
    .groupby('street')
    .count()
)

temp_df = temp_df.rename(columns={'median_level': f'occurance_weekday_{weekday}'})

# %% [markdown]
# ### Percentile Groupby

# %%
col = 'median_length'
prcntile = 75

def groupby_return_percentile(dataframe=jams_preprocess, prcntile=prcntile, col=col):
    return (
        dataframe
        .loc[:, [col, 'street']]
        .groupby('street')
        .apply(lambda x: np.percentile(x, prcntile))
        .reset_index()
        .rename(columns={0: f'percentile_{prcntile}_{col}'})
    )

# %% [markdown]
# ## Pipeline Feature Engineering

# %%
jams_feat_eng = jams_preprocess.copy()

# %%
def feat_eng_sel_numerical(dataframe=jams_preprocess):
    temp_df = (
        dataframe
        .loc[:, ['median_length', 'median_delay', 'median_speed_kmh', 'total_records', 'median_level', 'street']]
        .groupby('street')
        .agg(['mean', 'median', 'std'])
    )

    temp_df = temp_df.fillna(0)
    temp_df.columns = [f'{col[0]}__{col[1]}' for col in temp_df.columns]
    return temp_df

def feat_eng_overall_occurance(dataframe=jams_preprocess):
    # overall occurance
    temp_df = (
        dataframe
        .loc[:, ['street', 'median_level']]
        .groupby('street', as_index=False)
        .count()
    )

    temp_df = temp_df.rename(columns={'median_level': 'overall_occurance'})
    return temp_df

def feat_eng_occurance_timespan(dataframe=jams_preprocess, time_span=1):
    temp_df = (
        dataframe
        .query('time_span == @time_span')
        .loc[:, ['street', 'median_level']]
        .groupby('street', as_index=False)
        .count()
    )

    temp_df = temp_df.rename(columns={'median_level': f'occurance_time_span_{time_span}'})
    return temp_df

# %%
def feat_eng_occurance_weekday(dataframe=jams_preprocess, weekday=1):
    temp_df = (
        dataframe
        .query('weekday == @weekday')
        .loc[:, ['street', 'median_level']]
        .groupby('street', as_index=False)
        .count()
    )

    temp_df = temp_df.rename(columns={'median_level': f'occurance_weekday_{weekday}'})
    return temp_df

# %%
def pipeline_feat_eng(dataframe=jams_feat_eng):
    # sourcery skip: use-itertools-product
    
    # numerical
    temp_df = feat_eng_sel_numerical()
    dataframe = dataframe.merge(temp_df, how='left', left_on='street', right_index=True)
    dataframe = dataframe.drop_duplicates()
    
    # percentiles
    sel_cols = ['median_length', 'median_delay', 'median_speed_kmh', 'total_records', 'median_level']
    percs = [5, 25, 75, 95]
    
    for col in sel_cols:
        for prcntile in percs:
            temp_df = groupby_return_percentile(prcntile=prcntile, col=col)
            dataframe = dataframe.merge(temp_df, how='left', on='street')
            dataframe = dataframe.drop_duplicates()
            
    # overall_occurance
    temp_df = feat_eng_overall_occurance()
    dataframe = dataframe.merge(temp_df, how='left', on='street')
    dataframe = dataframe.drop_duplicates()
    
    # occurance_per_time_span
    for time_span in jams_preprocess.time_span.unique():
        temp_df = feat_eng_occurance_timespan(time_span=time_span)
        dataframe = dataframe.merge(temp_df, how='left', on='street')
        dataframe = dataframe.drop_duplicates()
        
    # occurance_per_weekday
    for weekday in jams_preprocess.weekday.unique():
        temp_df = feat_eng_occurance_weekday(weekday=weekday)
        dataframe = dataframe.merge(temp_df, how='left', on='street')
        dataframe = dataframe.drop_duplicates()
    
    return dataframe

# %%
jams_feat_eng = pipeline_feat_eng(jams_feat_eng)

# %%
for col in jams_feat_eng.select_dtypes('float64').columns:
    jams_feat_eng[col] = jams_feat_eng[col].astype('float32')
    
for col in jams_feat_eng.select_dtypes('int64').columns:
    jams_feat_eng[col] = jams_feat_eng[col].astype('int32')

# %%
jams_feat_eng.to_parquet('..\\dataset\\jams_bogor_feat_eng.parquet')
